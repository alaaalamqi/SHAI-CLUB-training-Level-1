# %% [markdown]
# # Matplotlib Exercises
#
# Welcome to the exercises for reviewing matplotlib! Take your time with these, Matplotlib can be tricky to understand at first. These are relatively simple plots, but they can be hard if this is your first time with matplotlib, feel free to ask about anything as you go along.
#
# Also don't worry if you find the matplotlib syntax frustrating, we actually won't be using it that often, we will switch to using seaborn and pandas built-in visualization capabilities. But, those are built-off of matplotlib, which is why it is still important to get exposure to it!
#
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.plot(x, y)
plt.axis([0, 100, 0, 200])
plt.xlabel("x")
plt.ylabel("y")
plt.title("title")

ax.tick_params(bottom=True, top=True, left=True, right=True,direction="in")
ax.set_xticks([0, 20, 40, 60, 80, 100])
ax.set_yticks([0, 50, 100, 150, 200])
plt.show()

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])
ax1.set_xticks(np.round(np.linspace(0, 1, 6),1))
ax1.set_yticks(np.round(np.linspace(0, 1, 6),1))
ax2.set_xticks(np.round(np.linspace(0, 1, 6),1))
ax2.set_yticks(np.round(np.linspace(0, 1, 6),1))
ax1.tick_params(bottom=True, top=True, left=True, right=True,direction="in")
ax2.tick_params(bottom=True, top=True, left=True, right=True,direction="in")

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig = plt.figure()

# Insert Figure Axes 1
ax1 = fig.add_axes([0,0,1,1])
ax1.axis([0, 100, 0, 200])
ax1.set_xticks(np.round(np.linspace(0, 100, 6),1))
ax1.set_yticks(np.round(np.linspace(0, 200, 5),1))
ax1.tick_params(bottom=True, top=True, left=True, right=True,direction="in")
ax1.plot(x, y,'r')


# Insert Figure Axes 2
ax2 = fig.add_axes([0.2,0.5,.2,.2])
ax2.axis([0, 100, 0, 200])
ax2.set_xticks(np.round(np.linspace(0, 100, 6),1))
ax2.set_yticks(np.round(np.linspace(0, 200, 5),1))
ax2.tick_params(bottom=True, top=True, left=True, right=True,direction="in")
ax2.plot(x, y,'r')

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.4,.4])
ax1.set_xticks(np.round(np.linspace(0, 1, 6),1))
ax1.set_yticks(np.round(np.linspace(0, 1, 6),1))
ax2.set_xticks(np.round(np.linspace(0, 1, 6),1))
ax2.set_yticks(np.round(np.linspace(0, 1, 6),1))
ax1.tick_params(bottom=True, top=True, left=True, right=True,direction="in")
ax2.tick_params(bottom=True, top=True, left=True, right=True,direction="in")

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

fig, (ax, ax2) = plt.subplots(2, 1)
axins = inset_axes(ax, width=1.3, height=0.9)

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig = plt.figure()
subplot1=fig.add_subplot(1,2,1)
subplot2=fig.add_subplot(1,2,2)
subplot1.tick_params(bottom=True, top=True, left=True, right=True,direction="in")
subplot2.tick_params(bottom=True, top=True, left=True, right=True,direction="in")

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,figsize=(6,4))

plt.subplot(1, 2, 1)
plt.xlim([0, 100])
plt.ylim([0, 200])
plt.tick_params(bottom=True, top=True, left=True, right=True,direction="in")
plt.plot(x,y,linewidth=4,linestyle="--")


plt.subplot(1, 2, 2)
plt.xlim([0, 100])
plt.ylim([0, 10000])
plt.tick_params(bottom=True, top=True, left=True, right=True,direction="in")
plt.plot(x,z,'r',linewidth=3)

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,figsize=(12,2))

plt.subplot(1, 2, 1)
plt.plot(x,y,linewidth=5)
plt.xlabel("x")
plt.ylabel("y")
plt.xlim([0, 100])
plt.ylim([0, 200])
plt.tick_params(bottom=True, top=True, left=True, right=True,direction="in")

plt.subplot(1, 2, 2)
plt.plot(x,z,'r',linewidth=3,linestyle="--")
plt.xlabel("x")
plt.ylabel("z")
plt.xlim([0, 100])
plt.ylim([0, 10000])
plt.tick_params(bottom=True, top=True, left=True, right=True,direction="in")

# %% [markdown]
# # Great Job!

# %% [markdown]
# ## #shAI Club
